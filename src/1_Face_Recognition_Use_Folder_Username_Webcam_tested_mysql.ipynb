# %%
import cv2
import numpy as np
import face_recognition
from PIL import Image
import glob
import re
import ntpath
import os
import dlib
import time
from imutils.face_utils import FaceAligner
import sqlite3
from imutils.face_utils import rect_to_bb
import imutils
from imutils import face_utils
import os
import shutil
import inception_resnet_v1
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime
import pymysql as MySQLdb
from sklearn.externals import joblib
from imutils.video import VideoStream
import math
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
# from wide_resnet import WideResNet

# img_size = 64
# model = WideResNet(img_size, depth=16, k=8)()
# model.load_weights("../gender_age_tf/weights.18-4.06.hdf5")

# %%
# show datetime now
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
date = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# 2018-06-27 17:50:18

# %%
# folder unknown_people through day
folder_name = "unknown_people"+date

# %%
# create folder unknown_people in day
os.mkdir("../data/" + folder_name)

# %%
# connect mysql 3 table data: people_known, people_inroom, people_unknown
people = MySQLdb.connect(host='localhost',
                      port=3306,
                      user='root',
                      passwd='hanoi1994',
                      db='people')
c = people.cursor()
c.execute('select * from people_known order by old')
for row in c:
    print(row)
c.execute('delete from people_inroom')
c.execute('select * from people_inroom order by old')
for row in c:
    print(row)
c.execute('delete from people_unknown')
c.execute('select * from people_unknown order by old')
for row in c:
    print(row)
    
c.execute('truncate table history_come')
people.commit()    
c.execute('select * from history_come')
for row in c:
    print(row)

# %%
# recognition face center
def face_center(image):
    image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    # detect rectangles from image faces
    rects = detector(image_gray, 1)
    for (i, rect) in enumerate(rects):
        points = predictor(image_gray, rect)
        points = face_utils.shape_to_np(points)
        
        # center face
        center_face = math.fabs(points[36][1] - points[45][1])
        
        # bias left right distance face
        left = points[36][0] - points[33][0]
        right = points[33][0] - points[45][0]
        bias_horizonal = math.fabs(left - right)
        
        if center_face < 25 and bias_horizonal < 20:
            return True
        else:
            return False

# %%
def _css_to_rect(css):
    """
    Convert a tuple in (top, right, bottom, left) order to a dlib `rect` object
    :param css:  plain tuple representation of the rect in (top, right, bottom, left) order
    :return: a dlib `rect` object
    """
    return dlib.rectangle(css[3], css[0], css[1], css[2])

# %%
# Load model and run graph inception resnet v1 from models and file resnetv1_inception.py
tf.reset_default_graph() 
# sess = tf.InteractiveSession()
sess = tf.Session()
images_pl = tf.placeholder(tf.float32, shape=[None, 160, 160, 3], name='input_image')
images_norm = tf.map_fn(lambda frame: tf.image.per_image_standardization(frame), images_pl)
train_mode = tf.placeholder(tf.bool)
age_logits, gender_logits, _ = inception_resnet_v1.inference(images_norm, keep_probability=0.8,
                                                             phase_train=train_mode,
                                                             weight_decay=1e-5)

# predict gender and age
gender = tf.argmax(tf.nn.softmax(gender_logits), 1)
age_ = tf.cast(tf.constant([i for i in range(0, 101)]), tf.float32)
age = tf.reduce_sum(tf.multiply(tf.nn.softmax(age_logits), age_), axis=1)
init_op = tf.group(tf.global_variables_initializer(),
                   tf.local_variables_initializer())

sess.run(init_op)
saver = tf.train.Saver()
ckpt = tf.train.get_checkpoint_state("../gender_age_tf/models/")
if ckpt and ckpt.model_checkpoint_path:
    saver.restore(sess, ckpt.model_checkpoint_path)
    print("restore model!")
else:
    pass
# Out:
# INFO:tensorflow:Restoring parameters from ../gender_age_tf/models/model.ckpt-14001
# restore model!

# %%
face_locations = [] # locations of all faces in image
face_encodings = [] # vecto encodings of all faces in image

name = ""

total_in_room = 0
total_known_in_room = 0
index = 0
# faces = np.empty((1,160, 160, 3))
faces = np.empty((1,160, 160, 3))
# faces_1 = np.empty((1,64, 64, 3))

# Load known_face_encoding_array and known_face name from npy
known_face_encodings_array = np.load("../data/numpy/known_face_encoding.npy")
known_face_names = np.load("../data/numpy/known_face_names.npy")

# Convert nparray -> list 
number_person = len(known_face_encodings_array)
known_face_encodings_array = known_face_encodings_array.reshape(number_person, 128)
known_face_encodings = []
for i in range(len(known_face_encodings_array)):
    known_face_encodings.append(known_face_encodings_array[i])

# face encodings of people in room
face_encodings_in_room = []
face_names_in_room = []

# face encodings of people unknown in room
face_encodings_unknown_in_room = []
face_names_unknown_in_room = []

# lib detect face in image
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
# lib aligner face in image 
fa = FaceAligner(predictor, desiredFaceWidth=160)

# fa_1 = FaceAligner(predictor, desiredFaceWidth=64)
# load svm classification for face encodings
# clf = joblib.load('svm_face_encodings.pkl')

# %%
def encoding_flip(image):
    image = np.fliplr(image)
    face_recognition.face_encodings(image)

# %%
# Capture from camera of own computer
# video_capture = cv2.VideoCapture(0)
# video_capture_extern = cv2.VideoCapture(1)
# video_capture.set(3, 1280)
# video_capture.set(4, 720)
video_capture = VideoStream(src=0).start()
# video_capture_extern = VideoStream(src=1).start()

while True:
    # COME IN
    # Grab a single frame of video
#     ret, frame = video_capture.read()
    now = datetime.datetime.now()
#     now = str(now).split(' ')[1]
    
    frame = video_capture.read()
#     frame = imutils.resize(frame, width=700, height=700)
    print(frame.shape)
    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_small_frame = frame[:, :, ::-1]
    
    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(rgb_small_frame)
    face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)
    
    # Use loop for ever face in image
    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        face_unknown = frame[top:bottom, left:right]
        frame_gray = cv2.cvtColor(rgb_small_frame, cv2.COLOR_BGR2GRAY)
        
        # test face center to process
        if face_center(face_unknown) == True:
            point = 1
            # compute distance between face come in with all face known
            if len(known_face_encodings) > 0:
                distance = face_recognition.face_distance(known_face_encodings, face_encoding)
                point = np.min(distance)
                print("point known face encoding in face center ", point)
                index_point_min = np.argmin(distance)
            
#             name = clf(face_encoding)
            
            if point > 0.45:
                if os.path.isfile("../data/" + folder_name + "/unknown_0.jpg"):
#                     print(face_encodings_unknown_in_room.shape)
#                     print(face_encoding.shape)
                    np.save("aaaa", face_encodings_unknown_in_room)
                    np.save("bbbb", face_encoding)
                    print(type(face_encodings_unknown_in_room))
                    print(len(face_encodings_unknown_in_room))
                    distance_unknown = face_recognition.face_distance(face_encodings_unknown_in_room, face_encoding)
                    min_distance_unknown = np.min(distance_unknown)
                    index_min_distance_unknown = np.argmin(distance_unknown)
                    
                    # min_distance > 0.44 unknown people new
                    if min_distance_unknown > 0.4:
                        a = os.listdir("../data/" + folder_name + "/")
                        a.sort()
                        index = int(a[-1].split('.')[0].split('_')[1])
                        index += 1
                        path = "../data/" + folder_name + "/unknown_" + str(index) + ".jpg"
                        name = "unknown_" + str(index)
                        cv2.imwrite(path, face_unknown)
                        
                        face_flip = np.fliplr(face_unknown)
                        face_flip_encoding = face_recognition.face_encodings(face_flip)[0]
                        print(face_flip_encoding)
                        face_encodings_unknown_in_room.append(face_flip_encoding)
                        print(type(face_encodings_unknown_in_room))
                        face_encodings_in_room.append(face_flip_encoding)
                        face_names_in_room.append(name)
                        face_names_unknown_in_room.append(name)
                        
                        face_encodings_in_room.append(face_encoding)
                        face_encodings_unknown_in_room.append(face_encoding)
                        face_names_in_room.append(name)
                        face_names_unknown_in_room.append(name)
                        print(name)
                        
                        
                        
                        # Draw a rectangle with detect the face
                        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                        # Draw a label with a name below the face
                        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                        font = cv2.FONT_HERSHEY_DUPLEX
                        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

                        # Estimate gender and age
                        # Convert to rect
                        face_detected = _css_to_rect((top, right, bottom, left))
                        print(face_detected)
                        faces[0, :, :, :] = fa.align(rgb_small_frame, frame_gray, face_detected)
#                         faces[0, :, :, :] = imutils.resize(rgb_small_frame, width=160, height=160)
                        age_predict, gender_predict = sess.run([age, gender], feed_dict={images_pl: faces, train_mode: False})
                        
                        label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
                        cv2.putText(frame, label, (left + 6, top - 6), font, 1.0, (255, 255, 255), 1)
                        
                        c.execute("insert into people_inroom values (%s, %s, %s)", (name, int(gender_predict), int(age_predict)))
                        people.commit()
                        c.execute("insert into people_unknown values (%s, %s, %s)", (name, int(gender_predict), int(age_predict)))
                        people.commit()
                        
                        #############################
                        c.execute("select max(id_time) from history_come where name='%s'"% name)
                        last_id_time = c.fetchone()[0]
                        if last_id_time == None:
                            record = [name, now]
                            c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                            people.commit()
                        else:
                            c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
                            come_out = c.fetchone()[0]
                            if come_out!=None:
                                record = [name, now]
                                c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                                people.commit()
                        
                    else:                      
                        name = face_names_unknown_in_room[index_min_distance_unknown]
                        # Draw a rectangle with detect the face
                        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                        # Draw a label with a name below the face
                        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                        font = cv2.FONT_HERSHEY_DUPLEX
                        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

                        c.execute("select * from people_unknown where name = '%s'" % name)
#                         print("show c.fetchone()", c.fetchone())
                        name, gender_predict, age_predict = c.fetchone()
                        label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
                        cv2.putText(frame, label, (left + 6, top - 6), font, 1.0, (255, 255, 255), 1)
                        
                        ###########################
                        c.execute("select max(id_time) from history_come where name='%s'"% name)
                        last_id_time = c.fetchone()[0]
                        if last_id_time == None:
                            record = [name, now]
                            c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                            people.commit()
                        else:
                            c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
                            come_out = c.fetchone()[0]
                            if come_out!=None:
                                record = [name, now]
                                c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                                people.commit()
                        
                else:
                    name = "unknown_0"
                    path = "../data/" + folder_name + "/unknown_0" + ".jpg"
                    cv2.imwrite(path, face_unknown)
                    face_encodings_unknown_in_room.append(face_encoding)
                    face_encodings_in_room.append(face_encoding)
                    face_names_in_room.append(name)
                    face_names_unknown_in_room.append(name)
                    
                    face_flip = np.fliplr(face_unknown)
                    face_flip_encoding = face_recognition.face_encodings(face_flip)[0]

                    face_encodings_unknown_in_room.append(face_flip_encoding)
                    face_encodings_in_room.append(face_flip_encoding)
                    face_names_in_room.append(name)
                    face_names_unknown_in_room.append(name)
                    
                    print(name)
                    print(len(face_encodings_unknown_in_room))

                    # Draw a rectangle with detect the face
                    cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                    # Draw a label with a name below the face
                    cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                    font = cv2.FONT_HERSHEY_DUPLEX
                    cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

                    # estimate gender and age
                    face_detected = _css_to_rect((top, right, bottom, left))
                    
                    faces[0, :, :, :] = fa.align(rgb_small_frame, frame_gray, face_detected)
                    age_predict, gender_predict = sess.run([age, gender], feed_dict={images_pl: faces, train_mode: False})
                    label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
                    cv2.putText(frame, label, (left + 6, top - 6), font, 1.0, (255, 255, 255), 1)

                    c.execute("insert into people_inroom values (%s, %s, %s)", (name, int(gender_predict), int(age_predict)))
                    people.commit()
                    c.execute("insert into people_unknown values (%s, %s, %s)", (name, int(gender_predict), int(age_predict)))
                    people.commit()
                    
                    #################
                    c.execute("select max(id_time) from history_come where name='%s'"% name)
                    last_id_time = c.fetchone()[0]
                    if last_id_time == None:
                        record = [name, now]
                        c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                        people.commit()
                    else:
                        c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
                        come_out = c.fetchone()[0]
                        if come_out!=None:
                            record = [name, now]
                            c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                            people.commit()

            else:

                face_encodings_in_room.append(face_encoding)
                name = known_face_names[index_point_min]
                face_names_in_room.append(name)
                # Draw a rectangle with detect the face
                cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                # Draw a label with a name below the face
                cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                font = cv2.FONT_HERSHEY_DUPLEX
                cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

                print(name)
                
                ########################
                c.execute("select max(id_time) from history_come where name='%s'"% name)
                last_id_time = c.fetchone()[0]
                if last_id_time == None:
                    record = [name, now]
                    c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                    people.commit()
                else:
                    c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
                    come_out = c.fetchone()[0]
                    if come_out!=None:
                        record = [name, now]
                        c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
                        people.commit()
                
                c.execute("select * from people_known where name= '%s'" % name)
                data_temp = c.fetchone()  # name in people known
                c.execute("select * from people_inroom where name='%s'" % name)
                data_name_inroom = c.fetchone() # name in room
                if data_name_inroom == None:
                    c.execute("insert into people_inroom values (%s, %s, %s)", (data_temp[0], ord(data_temp[1]), data_temp[2]))
                    people.commit()
                    
    
    total_in_room = c.execute("SELECT name FROM people_inroom")
    total_known_in_room = total_in_room - c.execute("SELECT name FROM people_unknown")
    print("total in people in room ", total_in_room)
    print("total in people known name in room ", total_known_in_room)
        
    # Display the resulting image
#     frame_extern = video_capture_extern.read()
    
#     # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
#     rgb_frame_extern = frame_extern[:, :, ::-1]
    
#     # Find all the faces and face encodings in the current frame of video
#     face_locations = face_recognition.face_locations(rgb_frame_extern)
#     face_encodings = face_recognition.face_encodings(rgb_frame_extern, face_locations)

#     for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
#         face_unknown = frame_extern[top:bottom, left:right]
#         frame_gray = cv2.cvtColor(rgb_frame_extern, cv2.COLOR_BGR2GRAY)
        
#         # test face center to process
#         if face_center(face_unknown) == True:

#             distance = face_recognition.face_distance(face_encodings_in_room, face_encoding)
#             point = np.min(distance)
#             index_point_min = np.argmin(distance)
#             name = face_names_in_room[index_point_min]
            
#             # Draw a rectangle with detect the face
#             cv2.rectangle(frame_extern, (left, top), (right, bottom), (0, 0, 255), 2)

#             # Draw a label with a name below the face
#             cv2.rectangle(frame_extern, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
#             font = cv2.FONT_HERSHEY_DUPLEX
#             cv2.putText(frame_extern, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)
            
#             c.execute("delete from people_inroom where name='%s'" % name)
#             people.commit()
            
#             #################
#             c.execute("select max(id_time) from history_come where name='%s'"% name)
#             last_id_time = c.fetchone()[0]
#             c.execute("update history_come SET come_out = '%s' where id_time = '%s'" % (now, last_id_time))
#             people.commit()
    
    cv2.imshow('Video', frame)
#     cv2.imshow('Video1', frame_extern)
    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
people.close()
# Out:
# (480, 640, 3)
# total in people in room  0
# total in people known name in room  0
# (480, 640, 3)
# unknown_0
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# total in people in room  1
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 2
# [ -4.29189764e-02   6.19945042e-02   7.95744881e-02  -8.24366733e-02
#   -6.93573058e-02  -9.64393280e-03  -8.31215829e-02  -9.93573293e-02
#    6.82245344e-02  -1.22063249e-01   2.77947903e-01  -6.23413213e-02
#   -2.31365889e-01  -6.65924698e-02  -7.15420544e-02   1.58357978e-01
#   -1.29693806e-01  -1.13978550e-01  -2.45552063e-02   4.85518500e-02
#    8.59332904e-02   2.64610797e-02   2.87809293e-03   1.27625745e-02
#   -7.86802843e-02  -3.47405374e-01  -9.90885422e-02  -7.79846832e-02
#   -6.88176528e-02  -4.45796624e-02   1.30618680e-02   3.86305079e-02
#   -1.73293293e-01   1.17169339e-02  -1.83284245e-02   4.14002948e-02
#   -5.98447397e-02  -1.31340316e-02   1.85508400e-01   6.06697835e-02
#   -2.13053405e-01   6.15052208e-02  -5.27264662e-02   2.71827519e-01
#    1.48600936e-01   9.13074538e-02   7.74096604e-03  -8.12121034e-02
#    6.37701452e-02  -2.56556481e-01   7.22877085e-02   1.16087623e-01
#    1.14414819e-01   4.59890589e-02   2.87726820e-02  -1.02218561e-01
#    3.16354632e-02   1.09408572e-01  -2.16861963e-01   4.51036319e-02
#   -1.06597468e-02  -1.02451868e-01   2.61901896e-02  -1.19748577e-01
#    2.66407073e-01   1.00108087e-01  -1.62867248e-01  -9.63291898e-02
#    1.19797722e-01  -1.02949575e-01  -1.12844214e-01   7.65838102e-02
#   -1.34674236e-01  -1.84795618e-01  -3.33971620e-01   5.53940050e-02
#    3.92857045e-01   1.03793748e-01  -2.51176924e-01  -3.05259842e-02
#   -2.41637342e-02  -1.57420225e-02   1.19420998e-01   1.16580367e-01
#    2.48207748e-02  -4.19796966e-02  -7.34214783e-02  -5.07379286e-02
#    1.91217214e-01  -1.05816118e-01  -1.14769384e-01   2.18674168e-01
#   -5.51059693e-02   7.84232095e-02  -3.09142750e-04   4.63877022e-02
#   -2.33041085e-02   2.89128851e-02  -8.28516483e-02   1.63563974e-02
#   -2.14783382e-03  -3.96326184e-02  -6.42621890e-02   1.09025382e-01
#   -1.27873033e-01   1.57140940e-01  -2.56515760e-02  -2.00265720e-02
#    9.99977812e-04   1.44373877e-02  -1.19885340e-01  -5.34004383e-02
#    1.30714566e-01  -2.94759929e-01   2.41827980e-01   1.89344719e-01
#    3.06919683e-02   1.19569823e-01   7.75962770e-02   4.65148240e-02
#   -4.28199768e-02  -2.69138608e-02  -2.21739635e-01  -1.06682576e-01
#    1.23244077e-01   1.81705840e-02   9.36576128e-02   1.09784417e-02]
# <class 'list'>
# unknown_1
# [(296, 282) (425, 411)]
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# ...
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)
# <class 'list'>
# 4
# total in people in room  2
# total in people known name in room  0
# (480, 640, 3)

# %%
# # Capture from camera of own computer
# # video_capture = cv2.VideoCapture(0)
# # video_capture_extern = cv2.VideoCapture(1)
# # video_capture.set(3, 1280)
# # video_capture.set(4, 720)
# video_capture = VideoStream(src=0).start()
# # video_capture_extern = VideoStream(src=1).start()

# while True:
#     # COME IN
#     # Grab a single frame of video
# #     ret, frame = video_capture.read()
#     now = datetime.datetime.now()
# #     now = str(now).split(' ')[1]
    
#     frame = video_capture.read()
#     frame = imutils.resize(frame, width=700, height=700)
#     print(frame.shape)
#     # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
#     rgb_small_frame = frame[:, :, ::-1]
    
#     # Find all the faces and face encodings in the current frame of video
#     face_locations = face_recognition.face_locations(rgb_small_frame)
#     face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)
    
#     # Use loop for ever face in image
#     for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
#         face_unknown = frame[top:bottom, left:right]
#         frame_gray = cv2.cvtColor(rgb_small_frame, cv2.COLOR_BGR2GRAY)
        
#         # test face center to process
#         if face_center(face_unknown) == True:
#             point = 1
#             # compute distance between face come in with all face known
#             if len(known_face_encodings) > 0:
#                 distance = face_recognition.face_distance(known_face_encodings, face_encoding)
#                 point = np.min(distance)
#                 print("point known face encoding in face center ", point)
#                 index_point_min = np.argmin(distance)
            
# #             name = clf(face_encoding)
            
#             if point > 0.45:
#                 if os.path.isfile("../data/" + folder_name + "/unknown_0.jpg"):
#                     distance_unknown = face_recognition.face_distance(face_encodings_unknown_in_room, face_encoding)
#                     min_distance_unknown = np.min(distance_unknown)
#                     index_min_distance_unknown = np.argmin(distance_unknown)
                    
#                     # min_distance > 0.44 unknown people new
#                     if min_distance_unknown > 0.4:
#                         a = os.listdir("../data/" + folder_name + "/")
#                         a.sort()
#                         index = int(a[-1].split('.')[0].split('_')[1])
#                         index += 1
#                         path = "../data/" + folder_name + "/unknown_" + str(index) + ".jpg"
#                         name = "unknown_" + str(index)
#                         cv2.imwrite(path, face_unknown)
#                         face_encodings_unknown_in_room.append(face_encoding)
#                         face_encodings_in_room.append(face_encoding)
#                         face_names_in_room.append(name)
#                         face_names_unknown_in_room.append(name)
#                         print(name)

#                         # Draw a rectangle with detect the face
#                         cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

#                         # Draw a label with a name below the face
#                         cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
#                         font = cv2.FONT_HERSHEY_DUPLEX
#                         cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

#                         # Estimate gender and age
#                         # Convert to rect
#                         face_detected = _css_to_rect((top, right, bottom, left))
#                         print(face_detected)
#                         faces[0, :, :, :] = fa.align(rgb_small_frame, frame_gray, face_detected)
                        
                        
#                         #####
#                         faces_1[0, :, :, :] = fa_1.align(rgb_small_frame, frame_gray, face_detected)

#                         result = model.predict(faces_1)
#                         gender_predict = result[0]
#                         age = np.arange(0, 101).reshape(101, 1)
#                         age_predict = result[1].dot(age).flatten()

#                         label_1 = "{}, {}".format(int(age_predict[0]),
#                                                  "F" if gender_predict[0][0] > 0.5 else "M")

#                         cv2.putText(frame, label_1, (left + 26, top - 6), font, 1.0, (255, 255, 255), 1)


#                         #####
                        
# #                         age_predict, gender_predict = sess.run([age, gender], feed_dict={images_pl: faces, train_mode: False})
                        
# #                         label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
# #                         cv2.putText(frame, label, (left + 6, top - 6), font, 1.0, (255, 255, 255), 1)
                        
#                         c.execute("insert into people_inroom values (%s, %s, %s)", (name, int(gender_predict[0][0]), int(age_predict[0])))
#                         people.commit()
#                         c.execute("insert into people_unknown values (%s, %s, %s)", (name, int(gender_predict[0][0]), int(age_predict[0])))
#                         people.commit()
                        
#                         #############################
#                         c.execute("select max(id_time) from history_come where name='%s'"% name)
#                         last_id_time = c.fetchone()[0]
#                         if last_id_time == None:
#                             record = [name, now]
#                             c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                             people.commit()
#                         else:
#                             c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
#                             come_out = c.fetchone()[0]
#                             if come_out!=None:
#                                 record = [name, now]
#                                 c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                                 people.commit()
                        
#                     else:                      
#                         name = "unknown_" + str(index_min_distance_unknown)
#                         # Draw a rectangle with detect the face
#                         cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

#                         # Draw a label with a name below the face
#                         cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
#                         font = cv2.FONT_HERSHEY_DUPLEX
#                         cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

#                         c.execute("select * from people_unknown where name = '%s'" % name)
# #                         print("show c.fetchone()", c.fetchone())
#                         name, gender_predict, age_predict = c.fetchone()
#                         label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
#                         cv2.putText(frame, label, (left + 6, top - 6), font, 1.0, (255, 255, 255), 1)
                        
#                         ###########################
#                         c.execute("select max(id_time) from history_come where name='%s'"% name)
#                         last_id_time = c.fetchone()[0]
#                         if last_id_time == None:
#                             record = [name, now]
#                             c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                             people.commit()
#                         else:
#                             c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
#                             come_out = c.fetchone()[0]
#                             if come_out!=None:
#                                 record = [name, now]
#                                 c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                                 people.commit()
                        
#                 else:
#                     name = "unknown_0"
#                     path = "../data/" + folder_name + "/unknown_0" + ".jpg"
#                     cv2.imwrite(path, face_unknown)
#                     face_encodings_unknown_in_room.append(face_encoding)
#                     face_encodings_in_room.append(face_encoding)
#                     face_names_in_room.append(name)
#                     face_names_unknown_in_room.append(name)
#                     print(name)

#                     # Draw a rectangle with detect the face
#                     cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

#                     # Draw a label with a name below the face
#                     cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
#                     font = cv2.FONT_HERSHEY_DUPLEX
#                     cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

#                     # estimate gender and age
#                     face_detected = _css_to_rect((top, right, bottom, left))
                    
#                     faces[0, :, :, :] = fa.align(rgb_small_frame, frame_gray, face_detected)
                    
#                     #####
#                     faces_1[0, :, :, :] = fa_1.align(rgb_small_frame, frame_gray, face_detected)

#                     result = model.predict(faces_1)
#                     gender_predict = result[0]
#                     age = np.arange(0, 101).reshape(101, 1)
#                     age_predict = result[1].dot(age).flatten()

#                     label_1 = "{}, {}".format(int(age_predict[0]),
#                                              "F" if gender_predict[0][0] > 0.5 else "M")

#                     cv2.putText(frame, label_1, (left + 26, top - 6), font, 1.0, (255, 255, 255), 1)


#                     #####
                        
                        
# #                     age_predict, gender_predict = sess.run([age, gender], feed_dict={images_pl: faces, train_mode: False})
# #                     label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
# #                     cv2.putText(frame, label, (left + 6, top - 6), font, 1.0, (255, 255, 255), 1)

#                     c.execute("insert into people_inroom values (%s, %s, %s)", (name, int(gender_predict[0][0]), int(age_predict[0])))
#                     people.commit()
#                     c.execute("insert into people_unknown values (%s, %s, %s)", (name, int(gender_predict[0][0]), int(age_predict[0])))
#                     people.commit()
                    
#                     #################
#                     c.execute("select max(id_time) from history_come where name='%s'"% name)
#                     last_id_time = c.fetchone()[0]
#                     if last_id_time == None:
#                         record = [name, now]
#                         c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                         people.commit()
#                     else:
#                         c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
#                         come_out = c.fetchone()[0]
#                         if come_out!=None:
#                             record = [name, now]
#                             c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                             people.commit()

#             else:

#                 face_encodings_in_room.append(face_encoding)
#                 name = known_face_names[index_point_min]
#                 face_names_in_room.append(name)
#                 # Draw a rectangle with detect the face
#                 cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

#                 # Draw a label with a name below the face
#                 cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
#                 font = cv2.FONT_HERSHEY_DUPLEX
#                 cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

#                 print(name)
                
#                 ########################
#                 c.execute("select max(id_time) from history_come where name='%s'"% name)
#                 last_id_time = c.fetchone()[0]
#                 if last_id_time == None:
#                     record = [name, now]
#                     c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                     people.commit()
#                 else:
#                     c.execute("select come_out from history_come where id_time='%d'"% last_id_time)
#                     come_out = c.fetchone()[0]
#                     if come_out!=None:
#                         record = [name, now]
#                         c.execute("insert into history_come(name, come_in) values(%s, %s)", record)
#                         people.commit()
                
#                 c.execute("select * from people_known where name= '%s'" % name)
#                 data_temp = c.fetchone()  # name in people known
#                 c.execute("select * from people_inroom where name='%s'" % name)
#                 data_name_inroom = c.fetchone() # name in room
#                 if data_name_inroom == None:
#                     c.execute("insert into people_inroom values (%s, %s, %s)", (data_temp[0], ord(data_temp[1]), data_temp[2]))
#                     people.commit()
                    
    
#     total_in_room = c.execute("SELECT name FROM people_inroom")
#     total_known_in_room = total_in_room - c.execute("SELECT name FROM people_unknown")
#     print("total in people in room ", total_in_room)
#     print("total in people known name in room ", total_known_in_room)
        
#     # Display the resulting image
# #     frame_extern = video_capture_extern.read()
    
# #     # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
# #     rgb_frame_extern = frame_extern[:, :, ::-1]
    
# #     # Find all the faces and face encodings in the current frame of video
# #     face_locations = face_recognition.face_locations(rgb_frame_extern)
# #     face_encodings = face_recognition.face_encodings(rgb_frame_extern, face_locations)

# #     for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
# #         face_unknown = frame_extern[top:bottom, left:right]
# #         frame_gray = cv2.cvtColor(rgb_frame_extern, cv2.COLOR_BGR2GRAY)
        
# #         # test face center to process
# #         if face_center(face_unknown) == True:

# #             distance = face_recognition.face_distance(face_encodings_in_room, face_encoding)
# #             point = np.min(distance)
# #             index_point_min = np.argmin(distance)
# #             name = face_names_in_room[index_point_min]
            
# #             # Draw a rectangle with detect the face
# #             cv2.rectangle(frame_extern, (left, top), (right, bottom), (0, 0, 255), 2)

# #             # Draw a label with a name below the face
# #             cv2.rectangle(frame_extern, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
# #             font = cv2.FONT_HERSHEY_DUPLEX
# #             cv2.putText(frame_extern, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)
            
# #             c.execute("delete from people_inroom where name='%s'" % name)
# #             people.commit()
            
# #             #################
# #             c.execute("select max(id_time) from history_come where name='%s'"% name)
# #             last_id_time = c.fetchone()[0]
# #             c.execute("update history_come SET come_out = '%s' where id_time = '%s'" % (now, last_id_time))
# #             people.commit()
    
#     cv2.imshow('Video', frame)
# #     cv2.imshow('Video1', frame_extern)
#     # Hit 'q' on the keyboard to quit!
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# people.close()
