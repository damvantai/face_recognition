# %%
import cv2
import datetime
import dlib
import face_recognition
import inception_resnet_v1
import numpy as np
import os
import sqlite3
import tensorflow as tf
import time

from imutils.face_utils import FaceAligner

# %%
start = time.time()

# %%
end = time.time()

# %%
end - start
# Out:
# 0.12244129180908203

# %%
import cv2
import numpy as np
import face_recognition
from PIL import Image
import glob
import re
import ntpath
import os
import dlib
import time
from imutils.face_utils import FaceAligner
import sqlite3
from imutils.face_utils import rect_to_bb
import imutils
from imutils import face_utils
import os
import shutil
import inception_resnet_v1
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime
import pymysql as MySQLdb

# %%
# show datetime now
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
date = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# 2018-12-23 21:03:15

# %%
folder_name = "unknown_people"+date

# %%
# shutil.rmtree("../data/unknown_people/")

# %%
# create folder unknown_people in day
os.mkdir("../data/" + folder_name)

# %%
people = sqlite3.connect('../data/people.db')
c = people.cursor()
# show name people know name
for row in c.execute('select * from people_known order by old'):
    print(row)
# delete people in table people inroom
c.execute('delete from people_inroom')
people.commit()
for row in c.execute('select * from people_inroom order by old'):
    print(row)
# delete id people unknow in table people unknow
c.execute('delete from people_unknown')
people.commit()
for row in c.execute('select * from people_unknown order by old'):
    print(row)
# Out:
# ('Dam Van Tai', 1, 24)
# ('Doan Van Dung', 1, 30)
# ('Tong Thi Thuy', 0, 32)
# ('Sakiyama', 1, 35)
# ('Pham Van Tuan', 1, 37)

# %%
# MYSQL
# people = MySQLdb.connect(host='localhost',
#                       port=3306,
#                       user='root',
#                       passwd='hanoi1994',
#                       db='people')
# c = conn.cursor

# %%
# Recognition face center
def face_center(image):
#     detector = dlib.get_frontal_face_detector()
#     predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
    image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    rects = detector(image_gray, 1)
    for (i, rect) in enumerate(rects):
        points = predictor(image_gray, rect)
        points = face_utils.shape_to_np(points)
        center_face = points[37][1] - points[46][1]
        if center_face < 20 & center_face > -20:
            return True
        else:
            return False

# %%
def _css_to_rect(css):
    """
    Convert a tuple in (top, right, bottom, left) order to a dlib `rect` object
    :param css:  plain tuple representation of the rect in (top, right, bottom, left) order
    :return: a dlib `rect` object
    """
    return dlib.rectangle(css[3], css[0], css[1], css[2])

# %%
# Load model and run graph
tf.reset_default_graph() 
# sess = tf.InteractiveSession()
sess = tf.Session()
images_pl = tf.placeholder(tf.float32, shape=[None, 160, 160, 3], name='input_image')
images_norm = tf.map_fn(lambda frame: tf.image.per_image_standardization(frame), images_pl)
train_mode = tf.placeholder(tf.bool)
age_logits, gender_logits, _ = inception_resnet_v1.inference(images_norm, keep_probability=0.8,
                                                             phase_train=train_mode,
                                                             weight_decay=1e-5)

gender = tf.argmax(tf.nn.softmax(gender_logits), 1)
age_ = tf.cast(tf.constant([i for i in range(0, 101)]), tf.float32)
age = tf.reduce_sum(tf.multiply(tf.nn.softmax(age_logits), age_), axis=1)
init_op = tf.group(tf.global_variables_initializer(),
                   tf.local_variables_initializer())
sess.run(init_op)
saver = tf.train.Saver()
ckpt = tf.train.get_checkpoint_state("../gender_age_tf/models/")
if ckpt and ckpt.model_checkpoint_path:
    saver.restore(sess, ckpt.model_checkpoint_path)
    print("restore model!")
else:
    pass
# Out:
# INFO:tensorflow:Restoring parameters from ../gender_age_tf/models/savedmodel.ckpt
# restore model!

# %%
# Initialize variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True
name = ""
frame_number = 0
total_in_room = 0
total_known_in_room = 0
index = 0
faces = np.empty((1,160, 160, 3))

font = cv2.FONT_HERSHEY_DUPLEX

# Load known_face_encoding_array and known_face name from npy
known_face_encodings_array = np.load("../data/numpy/known_face_encoding.npy")
known_face_names = np.load("../data/numpy/known_face_names.npy")
# known_face_names
# (19, 1, 128)
# array(['Dam Van Tai', 'Nguyen Chi Hieu', 'Nguyen Quoc Bao',
#        'Nguyen Chi Hieu', 'Doan Van Dung', 'Pham Van Tuan',
#        'Nguyen Minh Tan', 'Doan Van Dung', 'Dam Van Tai', 'Dam Van Tai',
#        'Doan Van Dung', 'Dam Van Tai', 'Nguyen Chi Hieu', 'Pham Van Tuan',
#        'Tong Thi Thuy', 'Nguyen Chi Hieu', 'Sakiyama', 'Nguyen Quoc Bao',
#        'Nguyen Quoc Bao'], dtype='<U15')


# Convert nparray -> list 
number_person = len(known_face_encodings_array)
known_face_encodings_array = known_face_encodings_array.reshape(number_person, 128)
known_face_encodings = []
for i in range(len(known_face_encodings_array)):
    known_face_encodings.append(known_face_encodings_array[i])

# face encodings of people in room
face_encodings_in_room = []
face_names_in_room = []
face_encodings_unknown_in_room = []
face_names_unknown_in_room = []
# known_face_encodings: array known_face_encodings 

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
fa = FaceAligner(predictor, desiredFaceWidth=160)

# %%
# Capture from camera of own computer
video_capture = cv2.VideoCapture(0)
# video_capture_extern = cv2.VideoCapture(1)

while True:
    start = time.time()
    # Grab a single frame of video
    ret, frame = video_capture.read()
    frame_number += 1
    
    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_small_frame = frame[:, :, ::-1]
    frame_gray = cv2.cvtColor(rgb_small_frame, cv2.COLOR_BGR2GRAY)
    # Use computer configuration low
#     if (frame_number % 3 == 0):
    # Only process every other frame of video to save time
#     if process_this_frame:

    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(rgb_small_frame)
    face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

    face_names = []
    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        face_unknown = frame[top:bottom, left:right]
#         face_unknown = cv2.cvtColor(face_unknown, cv2.COLOR_BGR2RGB)
#         face_unknown_gray = cv2.cvtColor(face_unknown, cv2.COLOR_BGR2GRAY)
#         frame_gray = cv2.cvtColor(rgb_small_frame, cv2.COLOR_BGR2GRAY)
    
        # test face center to process
        if face_center(face_unknown) == True:
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding, tolerance=0.4)

#             print(face_recognition.face_distance(known_face_encodings, face_encoding))
#             print(matches)
#             print(np.min(face_recognition.face_distance(known_face_encodings, face_encoding)))

            distance = face_recognition.face_distance(known_face_encodings, face_encoding)
            min_distance = np.min(distance)
            print("distance min with known face encodings: ", min_distance)
            index_point_min = np.argmin(distance)
#             print("gia tri cua index_point_min", index_point_min)
            if min_distance > 0.4:
                path = "../data/" + folder_name + "/unknown_0" + ".jpg"
                if os.path.isfile(path):
                    distance_unknown = face_recognition.face_distance(face_encodings_unknown_in_room, face_encoding)
                    if len(distance_unknown) > 0:
                        min_distance_unknown = np.min(distance_unknown)
                        index_min_distance_unknown = np.argmin(distance_unknown)
                        print(index_min_distance_unknown)

                        if min_distance_unknown > 0.4:
                            path = "../data/" + folder_name
                            a = os.listdir(path)
                            a.sort()
                            index = int(a[-1].split('.')[0].split('_')[1])
                            index += 1
#                             print("gia tri index", index)
                            name = "unknown_" + str(index)
                            face_encodings_unknown_in_room.append(face_encoding)
                            face_encodings_in_room.append(face_encoding)
                            face_names_in_room.append(name)
                            face_names_unknown_in_room.append(name)
                            total_in_room += 1
                            print(name)
                            
                            # Estimate gender and age
                            # Convert to rect
                            face_detected = _css_to_rect((top, right, bottom, left))
    #                         face_detected = detector(face_unknown, 1)
                            print(face_detected)
                            faces[0, :, :, :] = fa.align(rgb_small_frame, frame_gray, face_detected)
                            age_predict, gender_predict = sess.run([age, gender], feed_dict={images_pl: faces, train_mode: False})
                            
                            # Draw a rectangle with detect the face
                            cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                            # Draw a label with a name below the face
                            cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                            cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)
                            
                            label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
                            cv2.putText(frame, label, (left + 6, top + 20), font, 1.0, (255, 255, 255), 1)
                            
                            path = "../data/" + folder_name + "/unknown_" + str(index) + ".jpg"
                            cv2.imwrite(path, face_unknown)
                            
                            c.execute("insert into people_inroom values (?, ?, ?)", (name, int(gender_predict), int(age_predict)))
                            people.commit()
                            c.execute("insert into people_unknown values (?, ?, ?)", (name, int(gender_predict), int(age_predict)))
                            people.commit()

                        else:                      
                            name = "unknown_" + str(index_min_distance_unknown)
                            c.execute("select * from people_unknown where name = '%s'" % name)
    #                         print("show c.fetchone()", c.fetchone())
                            name, gender_predict, age_predict = c.fetchone()
                            label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
                            cv2.putText(frame, label, (left + 6, top - 6), font, 1.0, (255, 255, 255), 1)
                
                            # Draw a rectangle with detect the face
                            cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                            # Draw a label with a name below the face
                            cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                            cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

                else:
                    name = "unknown_0"
                    face_encodings_unknown_in_room.append(face_encoding)
                    face_encodings_in_room.append(face_encoding)
                    face_names_in_room.append(name)
                    face_names_unknown_in_room.append(name)
                    total_in_room += 1
                    print(name)
                    
                    
                    
                    # estimate gender and age
                    face_detected = _css_to_rect((top, right, bottom, left))
#                     face_detected = detector(face_unknown, 1)
                    
                    faces[0, :, :, :] = fa.align(rgb_small_frame, frame_gray, face_detected)
                    age_predict, gender_predict = sess.run([age, gender], feed_dict={images_pl: faces, train_mode: False})
            
                    label = "{}, {}".format(int(age_predict), "F" if gender_predict == 0 else "M")
                    cv2.putText(frame, label, (left + 6, top + 20), font, 1.0, (255, 255, 255), 1)
                    
                    # Draw a rectangle with detect the face
                    cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                    # Draw a label with a name below the face
                    cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                    cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)
                    
                    path = "../data/" + folder_name + "/unknown_0" + ".jpg"
                    cv2.imwrite(path, face_unknown)
                    
                    c.execute("insert into people_inroom values (?, ?, ?)", (name, int(gender_predict), int(age_predict)))
                    people.commit()
                    c.execute("insert into people_unknown values (?, ?, ?)", (name, int(gender_predict), int(age_predict)))
                    people.commit()

            # If a match was found in known_face_encodings, just use the first one.
            if True in matches:
#                 first_match_index = matches.index(True)
#                 print("gia tri cua first_match_index", first_match_index)
#                 first_match_index = matches[index_point_min]
#                 name = known_face_names[first_match_index]
                face_encodings_in_room.append(face_encoding)
                name = known_face_names[index_point_min]
                face_names_in_room.append(name)
                # Draw a rectangle with detect the face
                cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

                # Draw a label with a name below the face
                cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
                cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

                print(name)
                c.execute("select * from people_known where name= '%s'" % name)
                data_temp = c.fetchone()  # name in people known
                c.execute("select * from people_inroom where name='%s'" % name)
                data_name_inroom = c.fetchone() # name in room
                if data_name_inroom == None:
                    c.execute("insert into people_inroom values (?, ?, ?)", data_temp)
                    people.commit()
#                     total_in_room += 1
#                     total_known_in_room += 1
            face_names.append(name)
    
    total_in_room = c.execute("SELECT COUNT(*) FROM people_inroom").fetchone()[0]
    total_known_in_room = total_in_room - c.execute("SELECT COUNT(*) FROM people_unknown").fetchone()[0]
    print("total in people in room ", total_in_room)
    print("total in people known name in room ", total_known_in_room)
        
#     # Display the resulting image
#     ret_extern, frame_extern = video_capture_extern.read()
    
# #     frame_number += 1

#     # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
# #     rgb_frame = frame[:, :, ::-1]
#     rgb_frame_extern = frame_extern[:, :, ::-1]
    
#     # Use computer configuration low
# #     if (frame_number % 3 == 0):

#     # Find all the faces and face encodings in the current frame of video
#     face_locations = face_recognition.face_locations(rgb_frame_extern)
# #         print(face_locations)
#     face_encodings = face_recognition.face_encodings(rgb_frame_extern, face_locations)

#     face_names = []
#     for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
#         face_unknown = frame_extern[top:bottom, left:right]
# #         face_unknown = cv2.cvtColor(face_unknown, cv2.COLOR_BGR2RGB)
# #         face_unknown_gray = cv2.cvtColor(face_unknown, cv2.COLOR_BGR2GRAY)
#         frame_gray = cv2.cvtColor(rgb_frame_extern, cv2.COLOR_BGR2GRAY)
#         # test face center to process
#         if face_center(face_unknown) == True:
#             # See if the face is a match for the known face(s)
#             matches = face_recognition.compare_faces(face_encodings_in_room, face_encoding, tolerance=0.4)

# #             print(face_recognition.face_distance(known_face_encodings, face_encoding))
# #             print(matches)
# #             print(np.min(face_recognition.face_distance(known_face_encodings, face_encoding)))

#             distance = face_recognition.face_distance(face_encodings_in_room, face_encoding)
#             point = np.min(distance)
#             index_point_min = np.argmin(distance)
#             name = face_names_in_room[index_point_min]
            
#             # Draw a rectangle with detect the face
#             cv2.rectangle(frame_extern, (left, top), (right, bottom), (0, 0, 255), 2)

#             # Draw a label with a name below the face
#             cv2.rectangle(frame_extern, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
#             font = cv2.FONT_HERSHEY_DUPLEX
#             cv2.putText(frame_extern, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)
            
#             c.execute("delete from people_inroom where name=?", (name,))
#             people.commit()
    fps = 1. / (time.time() - start)
    print("FPS: ", fps)
    cv2.imshow('Video', frame)
#     cv2.imshow('Video1', frame_extern)
    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
people.close()
# Out:
# total in people in room  0
# total in people known name in room  0
# FPS:  0.6389792672807065
# total in people in room  0
# total in people known name in room  0
# FPS:  3.3038242499192614
# total in people in room  0
# total in people known name in room  0
# FPS:  1.5701905543074723
# total in people in room  0
# total in people known name in room  0
# FPS:  4.02887438872458
# total in people in room  0
# total in people known name in room  0
# FPS:  3.964074516175068
# total in people in room  0
# total in people known name in room  0
# FPS:  1.542356950693753
# total in people in room  0
# total in people known name in room  0
# FPS:  1.5924394601740546
# total in people in room  0
# total in people known name in room  0
# FPS:  1.5554963004938733
# total in people in room  0
# total in people known name in room  0
# FPS:  1.6157180949622063
# total in people in room  0
# total in people known name in room  0
# FPS:  1.604749776273386
# total in people in room  0
# total in people known name in room  0
# FPS:  1.6225296320366416
# total in people in room  0
# total in people known name in room  0
# FPS:  1.6022437426678977
# total in people in room  0
# total in people known name in room  0
# FPS:  3.933892141883723
# total in people in room  0
# total in people known name in room  0
# FPS:  3.785349934478663
# total in people in room  0
# total in people known name in room  0
# FPS:  3.9177427068388333
# total in people in room  0
# total in people known name in room  0
# FPS:  3.9608888217351477
# total in people in room  0
# total in people known name in room  0
# FPS:  3.962000051009179
# total in people in room  0
# total in people known name in room  0
# FPS:  3.975232890630257
# total in people in room  0
# total in people known name in room  0
# FPS:  3.941529755265094
# total in people in room  0
# total in people known name in room  0
# FPS:  3.9338884522387025
# total in people in room  0
# total in people known name in room  0
# FPS:  1.4639773878309505
# distance min with known face encodings:  0.3931745105515173
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.2835260931061223
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4308477141186529
# total in people in room  1
# total in people known name in room  1
# FPS:  3.3404645569267406
# total in people in room  1
# total in people known name in room  1
# FPS:  3.6282027770953644
# total in people in room  1
# total in people known name in room  1
# FPS:  3.70058981044013
# total in people in room  1
# total in people known name in room  1
# FPS:  3.39915084117618
# total in people in room  1
# total in people known name in room  1
# FPS:  3.524035896518145
# total in people in room  1
# total in people known name in room  1
# FPS:  3.5410270091381255
# total in people in room  1
# total in people known name in room  1
# FPS:  3.9822227623457525
# total in people in room  1
# total in people known name in room  1
# FPS:  3.9198260224312937
# total in people in room  1
# total in people known name in room  1
# FPS:  3.9514889551923833
# total in people in room  1
# total in people known name in room  1
# FPS:  3.95109438512371
# total in people in room  1
# total in people known name in room  1
# FPS:  3.982661391019816
# total in people in room  1
# total in people known name in room  1
# FPS:  3.781773066783039
# total in people in room  1
# total in people known name in room  1
# FPS:  3.6689153254023794
# total in people in room  1
# total in people known name in room  1
# FPS:  3.6758767259549443
# total in people in room  1
# total in people known name in room  1
# FPS:  3.8229955565683036
# total in people in room  1
# total in people known name in room  1
# FPS:  3.7330452018181477
# total in people in room  1
# total in people known name in room  1
# FPS:  3.7783220745574484
# total in people in room  1
# total in people known name in room  1
# FPS:  3.66571519964202
# total in people in room  1
# total in people known name in room  1
# FPS:  3.855618738750664
# total in people in room  1
# total in people known name in room  1
# FPS:  3.6180187391851164
# total in people in room  1
# total in people known name in room  1
# FPS:  3.7959219874202454
# total in people in room  1
# total in people known name in room  1
# FPS:  3.7554597508181455
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4759368299779962
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5631927220279036
# distance min with known face encodings:  0.38837063244774056
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4481043774879938
# distance min with known face encodings:  0.3853137267244468
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5238427409451645
# total in people in room  1
# total in people known name in room  1
# FPS:  1.1931442134850798
# distance min with known face encodings:  0.3211084039809416
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.2535911108480973
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4177949781785595
# distance min with known face encodings:  0.3280894460523623
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4017903783456798
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5283882830600242
# total in people in room  1
# total in people known name in room  1
# FPS:  1.478064108938891
# total in people in room  1
# total in people known name in room  1
# FPS:  1.346780467896834
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5127217749425017
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5330865367183069
# distance min with known face encodings:  0.29732679444795157
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4289032480493682
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4506827814290093
# total in people in room  1
# total in people known name in room  1
# FPS:  1.501716250621642
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4540931280185239
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5537054522811033
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5310986899359278
# distance min with known face encodings:  0.3344552799762513
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.542720022127637
# distance min with known face encodings:  0.3623367867158953
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4888026655942195
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5679992822268911
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5259200241568303
# total in people in room  1
# total in people known name in room  1
# FPS:  1.503207613979606
# distance min with known face encodings:  0.3818924725048464
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4055658249074754
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4315045373766595
# distance min with known face encodings:  0.38692682298232206
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.4917923578391847
# distance min with known face encodings:  0.36558054803778495
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.5539621866968396
# distance min with known face encodings:  0.3533848283401592
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.582022526156737
# distance min with known face encodings:  0.3575293165176515
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.47080158487197
# distance min with known face encodings:  0.36677225560678467
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.2553699541167702
# distance min with known face encodings:  0.3594401834994825
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.3761300410971757
# distance min with known face encodings:  0.36912069940852293
# Dam Van Tai
# total in people in room  1
# total in people known name in room  1
# FPS:  1.372909361816901
# distance min with known face encodings:  0.4956617594406674
# unknown_0
# total in people in room  2
# total in people known name in room  1
# FPS:  0.28493816257417603
# total in people in room  2
# total in people known name in room  1
# FPS:  1.591678636279977
# total in people in room  2
# total in people known name in room  1
# FPS:  1.6097366271822362
# total in people in room  2
# total in people known name in room  1
# FPS:  1.613779772348114
# total in people in room  2
# total in people known name in room  1
# FPS:  1.5830118977706589
# distance min with known face encodings:  0.3697224066642921
# Dam Van Tai
# total in people in room  2
# total in people known name in room  1
# FPS:  1.554113043339715
# distance min with known face encodings:  0.3495861550520606
# Dam Van Tai
# total in people in room  2
# total in people known name in room  1
# FPS:  1.5963881766221824
# total in people in room  2
# total in people known name in room  1
# FPS:  1.5862363691510355
# total in people in room  2
# total in people known name in room  1
# FPS:  1.6158643727730022
# total in people in room  2
# total in people known name in room  1
# FPS:  4.028940179281568
# total in people in room  2
# total in people known name in room  1
# FPS:  1.592287720798121
# total in people in room  2
# total in people known name in room  1
# FPS:  4.039408829041572
# total in people in room  2
# total in people known name in room  1
# FPS:  1.6079667174247407
# total in people in room  2
# total in people known name in room  1
# FPS:  1.6018203058972427
# total in people in room  2
# total in people known name in room  1
# FPS:  1.6159857723420616
# total in people in room  2
# total in people known name in room  1
# FPS:  3.913352671644618
# total in people in room  2
# total in people known name in room  1
# FPS:  3.8783359686352834
# total in people in room  2
# total in people known name in room  1
# FPS:  4.005202375063741
# distance min with known face encodings:  0.4397488208289437
# 0
# unknown_1
# [(283, 284) (469, 469)]
# total in people in room  3
# total in people known name in room  1
# FPS:  1.0890047571051502
# total in people in room  3
# total in people known name in room  1
# FPS:  3.787811248099007
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9468930115697503
# total in people in room  3
# total in people known name in room  1
# FPS:  4.000988250691346
# total in people in room  3
# total in people known name in room  1
# FPS:  4.034699362613726
# total in people in room  3
# total in people known name in room  1
# FPS:  1.589065716781879
# total in people in room  3
# total in people known name in room  1
# FPS:  4.028789251193229
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5927466546769966
# total in people in room  3
# total in people known name in room  1
# FPS:  1.585882509520655
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9388868802501773
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5448422986500736
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5196158990880066
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6095117784391706
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6167725099209982
# distance min with known face encodings:  0.47244507879045317
# 1
# total in people in room  3
# total in people known name in room  1
# FPS:  1.57879375198323
# total in people in room  3
# total in people known name in room  1
# FPS:  3.892571333113692
# total in people in room  3
# total in people known name in room  1
# FPS:  3.378617815318835
# total in people in room  3
# total in people known name in room  1
# FPS:  3.288028102214672
# distance min with known face encodings:  0.3357912759386362
# Dam Van Tai
# total in people in room  3
# total in people known name in room  1
# FPS:  1.544383824838181
# total in people in room  3
# total in people known name in room  1
# FPS:  1.559228353148175
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6272021793773086
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6223168827471717
# distance min with known face encodings:  0.4069832329337148
# 0
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6081615375885308
# distance min with known face encodings:  0.3693028427283873
# Dam Van Tai
# total in people in room  3
# total in people known name in room  1
# FPS:  1.556925943729781
# distance min with known face encodings:  0.40847689161004214
# 0
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5851153565910925
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5850284993467993
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6048068785133693
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6050199732822192
# total in people in room  3
# total in people known name in room  1
# FPS:  4.057709330797368
# total in people in room  3
# total in people known name in room  1
# FPS:  3.870315979075602
# total in people in room  3
# total in people known name in room  1
# FPS:  3.960066090733135
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9978839630131984
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6186849234711598
# total in people in room  3
# total in people known name in room  1
# FPS:  1.618298956940317
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6209594889980614
# total in people in room  3
# total in people known name in room  1
# FPS:  4.037468534766977
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9835313715974094
# total in people in room  3
# total in people known name in room  1
# FPS:  3.976152398648168
# total in people in room  3
# total in people known name in room  1
# FPS:  4.02121868417697
# total in people in room  3
# total in people known name in room  1
# FPS:  4.021592680733231
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9431935484477503
# total in people in room  3
# total in people known name in room  1
# FPS:  3.907402939189976
# total in people in room  3
# total in people known name in room  1
# FPS:  3.73554873139486
# total in people in room  3
# total in people known name in room  1
# FPS:  3.939393711703115
# total in people in room  3
# total in people known name in room  1
# FPS:  3.957170554520367
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9477808754515524
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9612928329785366
# total in people in room  3
# total in people known name in room  1
# FPS:  4.004881132208789
# total in people in room  3
# total in people known name in room  1
# FPS:  3.910422936501721
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9832930347757873
# total in people in room  3
# total in people known name in room  1
# FPS:  4.001717350776529
# total in people in room  3
# total in people known name in room  1
# FPS:  3.96088134082264
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9636137523837602
# total in people in room  3
# total in people known name in room  1
# FPS:  3.901583775648217
# total in people in room  3
# total in people known name in room  1
# FPS:  3.955573285500206
# total in people in room  3
# total in people known name in room  1
# FPS:  3.964318052502141
# total in people in room  3
# total in people known name in room  1
# FPS:  4.010705915314642
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9595763541496543
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9459906973943673
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9956864194614123
# total in people in room  3
# total in people known name in room  1
# FPS:  3.897711538211346
# total in people in room  3
# total in people known name in room  1
# FPS:  3.987352433971986
# total in people in room  3
# total in people known name in room  1
# FPS:  4.007540586067496
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9201630759366726
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9068533573775865
# total in people in room  3
# total in people known name in room  1
# FPS:  4.011415542582575
# total in people in room  3
# total in people known name in room  1
# FPS:  4.027539691532409
# total in people in room  3
# total in people known name in room  1
# FPS:  4.003413249440193
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8732681679033325
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9139661728683075
# total in people in room  3
# total in people known name in room  1
# FPS:  4.008367840961327
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8390147060034945
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9233496279916413
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9596025202166767
# total in people in room  3
# total in people known name in room  1
# FPS:  4.021858761867411
# total in people in room  3
# total in people known name in room  1
# FPS:  3.887469889121527
# total in people in room  3
# total in people known name in room  1
# FPS:  3.977298610511862
# total in people in room  3
# total in people known name in room  1
# FPS:  3.987572301596054
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8513702869127178
# total in people in room  3
# total in people known name in room  1
# FPS:  4.034567407213599
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9706154102482545
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8400375003662144
# total in people in room  3
# total in people known name in room  1
# FPS:  4.051888232407347
# total in people in room  3
# total in people known name in room  1
# FPS:  3.951771902997344
# total in people in room  3
# total in people known name in room  1
# FPS:  3.970626686849696
# total in people in room  3
# total in people known name in room  1
# FPS:  3.73795234946341
# total in people in room  3
# total in people known name in room  1
# FPS:  3.605559414349671
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8240098319344584
# total in people in room  3
# total in people known name in room  1
# FPS:  4.000831776931163
# total in people in room  3
# total in people known name in room  1
# FPS:  3.913202977326713
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9856322385200444
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9927271758024383
# total in people in room  3
# total in people known name in room  1
# FPS:  3.977117585759272
# total in people in room  3
# total in people known name in room  1
# FPS:  1.621598717042641
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6224580818009295
# total in people in room  3
# total in people known name in room  1
# FPS:  3.95099389401855
# total in people in room  3
# total in people known name in room  1
# FPS:  3.906263911680503
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9362290768081505
# total in people in room  3
# total in people known name in room  1
# FPS:  4.014656165888808
# total in people in room  3
# total in people known name in room  1
# FPS:  3.844659161844386
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9613601761988053
# total in people in room  3
# total in people known name in room  1
# FPS:  3.943512386282009
# total in people in room  3
# total in people known name in room  1
# FPS:  3.862535385590122
# total in people in room  3
# total in people known name in room  1
# FPS:  3.929344379168302
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9566628712875955
# total in people in room  3
# total in people known name in room  1
# FPS:  4.000587549669885
# total in people in room  3
# total in people known name in room  1
# FPS:  3.865165805806544
# total in people in room  3
# total in people known name in room  1
# FPS:  4.005007328613102
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8926327473461666
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9688157340688766
# total in people in room  3
# total in people known name in room  1
# FPS:  3.970803361968255
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9578763012674854
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9801292641659654
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8994472929440365
# total in people in room  3
# total in people known name in room  1
# FPS:  3.96403705170359
# total in people in room  3
# total in people known name in room  1
# FPS:  3.997502933100528
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9118234080573617
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8845463865871537
# total in people in room  3
# total in people known name in room  1
# FPS:  4.0394010485887195
# total in people in room  3
# total in people known name in room  1
# FPS:  4.014825251937391
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9963412403195315
# total in people in room  3
# total in people known name in room  1
# FPS:  4.006817018089554
# total in people in room  3
# total in people known name in room  1
# FPS:  4.003933001510196
# total in people in room  3
# total in people known name in room  1
# FPS:  4.0271800549016366
# total in people in room  3
# total in people known name in room  1
# FPS:  3.855058823529412
# total in people in room  3
# total in people known name in room  1
# FPS:  4.062000579136931
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9741631790243064
# total in people in room  3
# total in people known name in room  1
# FPS:  3.999012237387196
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9376739740868385
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9312926585572057
# total in people in room  3
# total in people known name in room  1
# FPS:  4.022564625863389
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9964897469930833
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9308726392106585
# total in people in room  3
# total in people known name in room  1
# FPS:  3.87227764637238
# total in people in room  3
# total in people known name in room  1
# FPS:  3.978630403108305
# total in people in room  3
# total in people known name in room  1
# FPS:  4.01037995452555
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9160527853871048
# total in people in room  3
# total in people known name in room  1
# FPS:  3.903962411494726
# total in people in room  3
# total in people known name in room  1
# FPS:  3.899305910636692
# distance min with known face encodings:  0.477632326312641
# 1
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6084470713927705
# total in people in room  3
# total in people known name in room  1
# FPS:  4.048958535452849
# distance min with known face encodings:  0.4282771678724146
# 1
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6126821297088423
# total in people in room  3
# total in people known name in room  1
# FPS:  4.056296620094524
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9761561679989077
# total in people in room  3
# total in people known name in room  1
# FPS:  3.928534699073012
# total in people in room  3
# total in people known name in room  1
# FPS:  3.7825131417924784
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9949024396283885
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9509901722239333
# total in people in room  3
# total in people known name in room  1
# FPS:  4.018822131622695
# total in people in room  3
# total in people known name in room  1
# FPS:  3.895962852633857
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9135060289190307
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6142865940020936
# total in people in room  3
# total in people known name in room  1
# FPS:  4.059032677006095
# total in people in room  3
# total in people known name in room  1
# FPS:  4.001942623897136
# total in people in room  3
# total in people known name in room  1
# FPS:  3.927552489985186
# total in people in room  3
# total in people known name in room  1
# FPS:  4.002313043312308
# total in people in room  3
# total in people known name in room  1
# FPS:  4.031596815711515
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9741443512305312
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9807903298672405
# total in people in room  3
# total in people known name in room  1
# FPS:  3.914112272941484
# total in people in room  3
# total in people known name in room  1
# FPS:  4.0244790337344725
# total in people in room  3
# total in people known name in room  1
# FPS:  4.007555902499429
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9717208217097424
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9155775291639907
# total in people in room  3
# total in people known name in room  1
# FPS:  4.002702630483992
# total in people in room  3
# total in people known name in room  1
# FPS:  4.027006060233653
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8823746118138187
# total in people in room  3
# total in people known name in room  1
# FPS:  3.956028450403733
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9950432288734774
# total in people in room  3
# total in people known name in room  1
# FPS:  3.971878787878788
# total in people in room  3
# total in people known name in room  1
# FPS:  3.825052551902128
# total in people in room  3
# total in people known name in room  1
# FPS:  4.003390322309695
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9492156751972582
# total in people in room  3
# total in people known name in room  1
# FPS:  3.954282977545939
# total in people in room  3
# total in people known name in room  1
# FPS:  4.001121835536621
# total in people in room  3
# total in people known name in room  1
# FPS:  4.009766524987046
# total in people in room  3
# total in people known name in room  1
# FPS:  4.015974645850987
# total in people in room  3
# total in people known name in room  1
# FPS:  3.972014197453701
# total in people in room  3
# total in people known name in room  1
# FPS:  3.7749996849894787
# total in people in room  3
# total in people known name in room  1
# FPS:  4.0329923711391755
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9224910595382383
# total in people in room  3
# total in people known name in room  1
# FPS:  3.985427732537699
# total in people in room  3
# total in people known name in room  1
# FPS:  4.024475172207995
# total in people in room  3
# total in people known name in room  1
# FPS:  3.973594658299417
# total in people in room  3
# total in people known name in room  1
# FPS:  4.019172574249646
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9414704923285973
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9712093984157972
# total in people in room  3
# total in people known name in room  1
# FPS:  4.018021349340389
# total in people in room  3
# total in people known name in room  1
# FPS:  4.041444446692741
# total in people in room  3
# total in people known name in room  1
# FPS:  4.052056554649045
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9670364488801075
# total in people in room  3
# total in people known name in room  1
# FPS:  4.014656165888808
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9975410328233996
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9347594004289084
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9533698291333
# total in people in room  3
# total in people known name in room  1
# FPS:  4.01741327604257
# total in people in room  3
# total in people known name in room  1
# FPS:  4.004047670870898
# total in people in room  3
# total in people known name in room  1
# FPS:  4.0179944054872205
# total in people in room  3
# total in people known name in room  1
# FPS:  3.835444473300145
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9369384590546774
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9726048416045736
# total in people in room  3
# total in people known name in room  1
# FPS:  3.980990581662764
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9495206115380923
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9937460603417576
# total in people in room  3
# total in people known name in room  1
# FPS:  4.025630098857856
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8793690608981652
# total in people in room  3
# total in people known name in room  1
# FPS:  3.956797245347987
# total in people in room  3
# total in people known name in room  1
# FPS:  3.943920277276805
# total in people in room  3
# total in people known name in room  1
# FPS:  3.884665113160225
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8263052648479805
# total in people in room  3
# total in people known name in room  1
# FPS:  3.891686460807601
# total in people in room  3
# total in people known name in room  1
# FPS:  3.781026464365462
# total in people in room  3
# total in people known name in room  1
# FPS:  3.996055681581081
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9678245429149572
# total in people in room  3
# total in people known name in room  1
# FPS:  4.011783880569605
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8778554813036936
# total in people in room  3
# total in people known name in room  1
# FPS:  1.637520472402518
# distance min with known face encodings:  0.5654299554707404
# 1
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5925325735496247
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8479005966841098
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9675317857234074
# total in people in room  3
# total in people known name in room  1
# FPS:  3.992415531407772
# total in people in room  3
# total in people known name in room  1
# FPS:  4.005726417445899
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9910137334588085
# total in people in room  3
# total in people known name in room  1
# FPS:  4.027539691532409
# total in people in room  3
# total in people known name in room  1
# FPS:  1.587088078517705
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9839097425843764
# total in people in room  3
# total in people known name in room  1
# FPS:  1.614745865352891
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6389031944964352
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6280851899624993
# total in people in room  3
# total in people known name in room  1
# FPS:  1.606599989044962
# total in people in room  3
# total in people known name in room  1
# FPS:  1.632440952849851
# total in people in room  3
# total in people known name in room  1
# FPS:  3.904151374033225
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6095902212776703
# total in people in room  3
# total in people known name in room  1
# FPS:  1.62472753698079
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5750562814617597
# total in people in room  3
# total in people known name in room  1
# FPS:  4.085996491012725
# total in people in room  3
# total in people known name in room  1
# FPS:  3.99963763658955
# total in people in room  3
# total in people known name in room  1
# FPS:  4.005072341985852
# total in people in room  3
# total in people known name in room  1
# FPS:  3.7861255866309085
# total in people in room  3
# total in people known name in room  1
# FPS:  3.962733729074097
# total in people in room  3
# total in people known name in room  1
# FPS:  4.014936702802307
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9952943910856336
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9225387479273492
# total in people in room  3
# total in people known name in room  1
# FPS:  4.01865270875311
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9179330057727877
# total in people in room  3
# total in people known name in room  1
# FPS:  3.938491124482606
# total in people in room  3
# total in people known name in room  1
# FPS:  3.961128225856718
# total in people in room  3
# total in people known name in room  1
# FPS:  4.007666950132337
# total in people in room  3
# total in people known name in room  1
# FPS:  3.975579540424467
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6272533147936634
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6328673860521032
# total in people in room  3
# total in people known name in room  1
# FPS:  1.625611643403708
# total in people in room  3
# total in people known name in room  1
# FPS:  1.636448407426612
# total in people in room  3
# total in people known name in room  1
# FPS:  4.037134323646132
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6163407372353404
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6293570682710954
# total in people in room  3
# total in people known name in room  1
# FPS:  1.6270197594481723
# total in people in room  3
# total in people known name in room  1
# FPS:  3.9288033286560795
# total in people in room  3
# total in people known name in room  1
# FPS:  3.986336808690611
# total in people in room  3
# total in people known name in room  1
# FPS:  3.720191619443289
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4593243685678607
# total in people in room  3
# total in people known name in room  1
# FPS:  3.4577055326698165
# total in people in room  3
# total in people known name in room  1
# FPS:  1.497704150953637
# total in people in room  3
# total in people known name in room  1
# FPS:  3.71877659876298
# total in people in room  3
# total in people known name in room  1
# FPS:  3.8707517333601578
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4909751706996623
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5486971615553642
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5704709948216404
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4725102197581523
# total in people in room  3
# total in people known name in room  1
# FPS:  3.529323065323927
# total in people in room  3
# total in people known name in room  1
# FPS:  1.44448370510423
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4578903901607525
# distance min with known face encodings:  0.4258258035661641
# 0
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4333253026458552
# total in people in room  3
# total in people known name in room  1
# FPS:  1.28134046481732
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5562835495980263
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5526454509378869
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5270116574557475
# total in people in room  3
# total in people known name in room  1
# FPS:  1.504046898190864
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5222659721997907
# total in people in room  3
# total in people known name in room  1
# FPS:  1.521850064004505
# total in people in room  3
# total in people known name in room  1
# FPS:  1.421945462817499
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5501865152418415
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5343994819856486
# total in people in room  3
# total in people known name in room  1
# FPS:  1.3132360782486696
# total in people in room  3
# total in people known name in room  1
# FPS:  1.2427718381171446
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4954512198774346
# total in people in room  3
# total in people known name in room  1
# FPS:  1.3552505690896666
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4391275004057331
# distance min with known face encodings:  0.40536195525897556
# 0
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4390331934889324
# total in people in room  3
# total in people known name in room  1
# FPS:  1.4561143866102733
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5058937068330092
# distance min with known face encodings:  0.4165614576110333
# 0
# total in people in room  3
# total in people known name in room  1
# FPS:  1.5068621206128037
# total in people in room  3
# total in people known name in room  1
# FPS:  1.497057321289689
# total in people in room  3
# total in people known name in room  1
# FPS:  1.355898539330492
# distance min with known face encodings:  0.39215839208741066
# Dam Van Tai
# total in people in room  3
# total in people known name in room  1
# FPS:  1.357979819564306
